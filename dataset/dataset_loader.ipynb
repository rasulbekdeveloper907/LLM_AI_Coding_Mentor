# %%
# !pip install datasets

# %%
from datasets import load_dataset

dataset = load_dataset(
    "ise-uiuc/Magicoder-Evol-Instruct-110K",
    split="train"
)

print(dataset)
# Out:
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# README.md:   0%|          | 0.00/394 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# data-evol_instruct-decontaminated.jsonl: reconstructing file:   0%|          |  0.00B /  255MB
# data-evol_instruct-decontaminated.jsonl: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/111183 [00:00<?, ? examples/s]
# Dataset({
#     features: ['instruction', 'response'],
#     num_rows: 111183
# })

# %%
from pathlib import Path
import json

RAW_DIR = Path("/content/AI_Coding_Mentor/data/raw")
RAW_DIR.mkdir(parents=True, exist_ok=True)

output_file = RAW_DIR / "magicoder_evol_instruct_110k.jsonl"

with open(output_file, "w", encoding="utf-8") as f:
    for item in dataset:
        record = {
            "instruction": item["instruction"],
            "response": item["response"]
        }

        f.write(
            json.dumps(record, ensure_ascii=False) + "\n"
        )

print("Saved:", output_file)
print("Records:", len(dataset))
# Out:
# Saved: /content/AI_Coding_Mentor/data/raw/magicoder_evol_instruct_110k.jsonl
# Records: 111183

# %%
from pathlib import Path

path = Path("/content/AI_Coding_Mentor/data/raw/magicoder_evol_instruct_110k.jsonl")

print("Exists:", path.exists())
print("Size MB:", path.stat().st_size / (1024 * 1024))
# Out:
# Exists: True
# Size MB: 243.07940101623535

# %%
from pathlib import Path

file_path = Path(
    "/content/AI_Coding_Mentor/data/raw/magicoder_evol_instruct_110k.jsonl"
)

print("Exists:", file_path.exists())
print("Size:", file_path.stat().st_size / (1024**2), "MB")
# Out:
# Exists: True
# Size: 243.07940101623535 MB

# %%
from google.colab import files

files.download(str(file_path))

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
from pathlib import Path

source = Path(
    "/content/AI_Coding_Mentor/data/raw/magicoder_evol_instruct_110k.jsonl"
)

destination = Path(
    "/content/drive/MyDrive/AI_Coding_Mentor/magicoder_evol_instruct_110k.jsonl"
)

destination.parent.mkdir(parents=True, exist_ok=True)

shutil.copy2(source, destination)

print("Copied successfully!")
print(destination)
print("Size:", destination.stat().st_size / (1024**2), "MB")
# Out:
# Copied successfully!
# /content/drive/MyDrive/AI_Coding_Mentor/magicoder_evol_instruct_110k.jsonl
# Size: 243.07940101623535 MB
